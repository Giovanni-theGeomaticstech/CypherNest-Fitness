# %% [markdown]
# #This Document will be used to turn our Python Code into an Android or IOS APP

# %% [markdown]
# ### Install and Setup Buildozer.
# * The package to build our application

# %%
# !sudo apt install git

# This is the Buildozer install
# %cd ..
# !sudo rm -r buildozer
# !git clone https://github.com/kivy/buildozer.git
# %cd buildozer

# Setup up Buildozer
# !sudo apt-get install python3-setuptools
# !pip install setuptools
# !sudo python setup.py install
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# git is already the newest version (1:2.17.1-1ubuntu0.8).
# 0 upgraded, 0 newly installed, 0 to remove and 30 not upgraded.
# Cloning into 'buildozer'...
# remote: Enumerating objects: 64, done.
# remote: Counting objects: 100% (64/64), done.
# remote: Compressing objects: 100% (50/50), done.
# remote: Total 4050 (delta 34), reused 25 (delta 14), pack-reused 3986
# Receiving objects: 100% (4050/4050), 1.39 MiB | 16.75 MiB/s, done.
# Resolving deltas: 100% (2529/2529), done.
# /content/buildozer
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   python3-pkg-resources
# Suggested packages:
#   python-setuptools-doc
# The following NEW packages will be installed:
#   python3-pkg-resources python3-setuptools
# 0 upgraded, 2 newly installed, 0 to remove and 30 not upgraded.
# ...

# %% [markdown]
# ### Install other Packages (i.e. C, C++, Java and Other Linux packages)
# * To get our application to build with buildozer
# * Allows us to not have to write code in any other language

# %%
# !sudo apt update
# !sudo apt install -y git zip unzip openjdk-8-jdk python3-pip autoconf libtool pkg-config zlib1g-dev libncurses5-dev libncursesw5-dev libtinfo5 cmake libffi-dev libssl-dev

# !pip install cython
# !sudo apt-get install cython

# !sudo apt-get install build-essential libsqlite3-dev sqlite3 bzip2 libbz2-dev zlib1g-dev libssl-dev openssl libgdbm-dev libgdbm-compat-dev liblzma-dev libreadline-dev libncursesw5-dev libffi-dev uuid-dev libffi6
# Out:
# Hit:1 http://security.ubuntu.com/ubuntu bionic-security InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease
# Ign:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:4 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Ign:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:8 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:9 http://archive.ubuntu.com/ubuntu bionic-updates InRelease
# Hit:10 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:11 http://archive.ubuntu.com/ubuntu bionic-backports InRelease
# Hit:12 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# ...

# %% [markdown]
# ### Copy the code from the git repository and Change into that directory

# %%
# Full App
# %cd ..
# IDEALLY FOR FINAL APP WE USE Github
# !sudo rm -r GPS_APP
# !cp -r drive/MyDrive/AppDev/Working_APP GPS_APP
# # !mkdir GPS_APP
# %cd GPS_APP

git clone https://github.com/Giovanni-theGeomaticstech/CypherNest-Fitness.git
# %cd CypherNest-Fitness
# Out:
# /content
# /content/GPS_APP

# %% [markdown]
# ### Run this cell to build the android or ios app
# * Note you need to allow it to run
# * Accept all the licenses

# %%
# !buildozer -v android debug
# Out:
# Streaming output truncated to the last 5000 lines.
# Compiling '/content/GPS_APP/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_21/python3/Lib/test/test_functools.py'...
# Compiling '/content/GPS_APP/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_21/python3/Lib/test/test_future.py'...
# Compiling '/content/GPS_APP/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_21/python3/Lib/test/test_future3.py'...
# Compiling '/content/GPS_APP/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_21/python3/Lib/test/test_future4.py'...
# Compiling '/content/GPS_APP/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_21/python3/Lib/test/test_future5.py'...
# ...

# %% [markdown]
# ### Clean the Environment
# * Useful if you want to make changes to the code and want to rebuild application

# %%
# Clean the build environment 
# Do this before building everytime to prevent any issues
# !buildozer android clean
# Out:
# # Check configuration tokens
# Buildozer is running as root!
# This is not recommended, and may lead to problems later.
# Are you sure you want to continue [y/n]? y
# # Ensure build layout
# # Check configuration tokens
# # Run '/usr/bin/python3 -m pythonforandroid.toolchain clean_builds --color=always --storage-dir="/content/GPS_APP/.buildozer/android/platform/build-armeabi-v7a" --ndk-api=21 --ignore-setup-py'
# # Cwd /content/GPS_APP/.buildozer/android/platform/python-for-android
# /content/GPS_APP/.buildozer/android/platform/python-for-android/pythonforandroid/toolchain.py:84: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   import imp
# # Run '/usr/bin/python3 -m pythonforandroid.toolchain clean_dists --color=always --storage-dir="/content/GPS_APP/.buildozer/android/platform/build-armeabi-v7a" --ndk-api=21 --ignore-setup-py'
# # Cwd /content/GPS_APP/.buildozer/android/platform/python-for-android
# ...

# %% [markdown]
# ### Only run this if you want a non edited buildozer.spec file
# * Otherwise for the purpose of this tutorial do not run uncomment and run cell.

# %%
# !buildozer init
